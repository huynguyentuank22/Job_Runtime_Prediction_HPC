# %%
import pandas as pd
import os

# %%
for data in os.listdir(r'output_csv'):
    df = pd.read_csv(os.path.join('output_csv', data))
    # Check all collumn can not astype to float
    try:
        df = df.astype(float)
    except ValueError:
        print(f"File {data} contains non-numeric data.")
        continue
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_20180\3174535411.py:2: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join('output_csv', data))
# File METACENTRUM-2013-3.swf.csv contains non-numeric data.

# %%
df = pd.read_csv(r'output_csv/METACENTRUM-2013-3.swf.csv')

col_name = df.columns[15]
bad_rows = pd.to_numeric(df[col_name], errors='coerce').isna()
data = df[bad_rows]
data
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_20180\1061698155.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'output_csv/METACENTRUM-2013-3.swf.csv')
#             job_id  submit_time  wait_time  run_time  \
# 13330      13331.0     383927.0        1.0   86609.0
# 13343      13344.0     384243.0        2.0   39920.0
# 13369      13370.0     387771.0       13.0   36382.0
# 13488      13489.0     393327.0        1.0   86411.0
# 13492      13493.0     393388.0        1.0     231.0
# ...            ...          ...        ...       ...
# 5724964  5724965.0   62969077.0     2435.0       5.0
# 5724965  5724966.0   62969077.0     2531.0      16.0
# 5724966  5724967.0   62969078.0     3045.0       6.0
# 5724967  5724968.0   62969087.0     2827.0      10.0
# 5724968  5724969.0   62969087.0     2936.0       4.0
#
#          num_allocated_processors  avg_cpu_time_used  used_memory  \
# ...

# %%
for data in os.listdir(r'output_csv'):
    df = pd.read_csv(os.path.join('output_csv', data))
    print(df['status'].value_counts())
# Out:
# status
# -1.0    68936
# Name: count, dtype: int64
# status
# 1.0    281337
# 5.0     17486
# 0.0     14003
# Name: count, dtype: int64
# status
#  1.0    6452617
#  0.0    1464661
#  5.0    1007512
# -1.0     338222
# Name: count, dtype: int64
# status
# 1.0    63946
# 0.0    11998
# Name: count, dtype: int64
# status
# 1.0    60553
# 0.0    16669
# Name: count, dtype: int64
# status
# 1.0    192269
# 5.0     30799
# 0.0      2643
# Name: count, dtype: int64
# status
# 1.0    34808
# 5.0     3953
# 0.0     1554
# Name: count, dtype: int64
# status
# 1.0    61040
# 5.0     3395
# 0.0     1994
# Name: count, dtype: int64
# status
# 1.0    62767
# 5.0     2827
# 0.0     1143
# Name: count, dtype: int64
# status
# 1.0    29563
# 5.0     3630
# 0.0      602
# Name: count, dtype: int64
# status
#  1.0    201993
# -1.0       878
# Name: count, dtype: int64
# status
# 1.0    9129288
# 0.0    4238903
# Name: count, dtype: int64
# status
# 0.0    7428814
# 1.0    5656978
# ...
